# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ### Loading RPPA and CRIPSR data from Local Directory

# %%
df_rppa=pd.read_csv("RPPA.csv")
df_DepMap=pd.read_csv("DepMap.csv")
df_crispr=pd.read_csv("gene_dependency.csv")

# %%
df_DepMap.head()
# Out:
#     DepMap_ID                                   CCLE_Name             Aliases  \
# 0  ACH-000001                             NIHOVCAR3_OVARY  NIH:OVCAR-3;OVCAR3
# 1  ACH-000002     HL60_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE               HL-60
# 2  ACH-000003                       CACO2_LARGE_INTESTINE  CACO2;CACO2;CaCo-2
# 3  ACH-000004      HEL_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE                 HEL
# 4  ACH-000005  HEL9217_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE          HEL 92.1.7
#
#    COSMIC_ID  Sanger ID          Primary Disease  \
# 0   905933.0     2201.0           Ovarian Cancer
# 1   905938.0       55.0                 Leukemia
# 2        NaN        NaN  Colon/Colorectal Cancer
# 3   907053.0      783.0                 Leukemia
# 4        NaN        NaN                 Leukemia
#
#                                      Subtype Disease  Gender Source
# 0                  Adenocarcinoma, high grade serous  Female   ATCC
# 1  Acute Myelogenous Leukemia (AML), M3 (Promyelo...  Female   ATCC
# 2                               Colon Adenocarcinoma      -1    NaN
# 3  Acute Myelogenous Leukemia (AML), M6 (Erythrol...    Male   DSMZ
# 4  Acute Myelogenous Leukemia (AML), M6 (Erythrol...    Male   ATCC

# %%
df_crispr.head()
# Out:
#          line      A1BG      A1CF       A2M     A2ML1   A3GALT2    A4GALT  \
# 0  ACH-000004  0.002472  0.006113  0.080820  0.014331  0.011727  0.086325
# 1  ACH-000005  0.106867  0.002193  0.013620  0.003971  0.057068  0.181176
# 2  ACH-000007  0.008004  0.005757  0.022515  0.002067  0.004548  0.002647
# 3  ACH-000009  0.005477  0.013870  0.010608  0.006887  0.007972  0.012466
# 4  ACH-000011  0.001426  0.006870  0.020701  0.000096  0.031714  0.157628
#
#       A4GNT      AAAS      AACS  ...  UHRF1BP1L     UHRF2     UIMC1     ULBP1  \
# 0  0.000195  0.385731  0.000323  ...   0.000226  0.482277  0.088692  0.105547
# 1  0.006674  0.226020  0.022460  ...   0.129011  0.173723  0.111182  0.248581
# 2  0.006611  0.350966  0.015407  ...   0.007540  0.009939  0.298588  0.004260
# 3  0.007143  0.654158  0.002847  ...   0.011120  0.043010  0.114406  0.003146
# 4  0.008184  0.325639  0.005510  ...   0.002486  0.190601  0.212744  0.004571
#
#       ULBP2     ULBP3      ULK1      ULK2      ULK3      ULK4
# 0  0.251080  0.012645  0.125621  0.001633  0.026469  0.000128
# 1  0.002710  0.030146  0.030472  0.000230  0.022362  0.000945
# 2  0.053709  0.064741  0.005785  0.053324  0.015700  0.000100
# 3  0.085866  0.065066  0.040335  0.101210  0.014466  0.000668
# 4  0.027059  0.261925  0.305681  0.104093  0.022448  0.001405
#
# [5 rows x 16384 columns]

# %% [markdown]
# ## Finding the CRISPR gene CCLE_Name from DepMap data

# %% [markdown]
# This section replaced the DepMap_id of CRISPR Gene by CCLE Name which then will compare with the RPPA dataset

# %%
crispr=df_crispr.line

# %%
for i in crispr:
    for j in df_DepMap.DepMap_ID:
        if i==j:
            a=df_DepMap.loc[df_DepMap['DepMap_ID'] == j]
            b=df_crispr.loc[df_crispr['line'] == i].index.values
            df_crispr.iloc[b[0],0]=a.iloc[0,1]

# %%
df_crispr.set_index("line", inplace=True)
df_crispr.head()
# Out:
#                                                 A1BG      A1CF       A2M  \
# line
# HEL_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE      0.002472  0.006113  0.080820
# HEL9217_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE  0.106867  0.002193  0.013620
# LS513_LARGE_INTESTINE                       0.008004  0.005757  0.022515
# C2BBE1_LARGE_INTESTINE                      0.005477  0.013870  0.010608
# 253J_URINARY_TRACT                          0.001426  0.006870  0.020701
#
#                                                A2ML1   A3GALT2    A4GALT  \
# line
# HEL_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE      0.014331  0.011727  0.086325
# HEL9217_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE  0.003971  0.057068  0.181176
# LS513_LARGE_INTESTINE                       0.002067  0.004548  0.002647
# C2BBE1_LARGE_INTESTINE                      0.006887  0.007972  0.012466
# 253J_URINARY_TRACT                          0.000096  0.031714  0.157628
#
#                                                A4GNT      AAAS      AACS  \
# line
# HEL_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE      0.000195  0.385731  0.000323
# HEL9217_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE  0.006674  0.226020  0.022460
# LS513_LARGE_INTESTINE                       0.006611  0.350966  0.015407
# C2BBE1_LARGE_INTESTINE                      0.007143  0.654158  0.002847
# 253J_URINARY_TRACT                          0.008184  0.325639  0.005510
#
#                                                AADAC  ...  UHRF1BP1L  \
# line                                                  ...
# HEL_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE      0.002680  ...   0.000226
# HEL9217_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE  0.017682  ...   0.129011
# LS513_LARGE_INTESTINE                       0.000335  ...   0.007540
# C2BBE1_LARGE_INTESTINE                      0.005807  ...   0.011120
# 253J_URINARY_TRACT                          0.005072  ...   0.002486
#
#                                                UHRF2     UIMC1     ULBP1  \
# line
# HEL_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE      0.482277  0.088692  0.105547
# HEL9217_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE  0.173723  0.111182  0.248581
# LS513_LARGE_INTESTINE                       0.009939  0.298588  0.004260
# C2BBE1_LARGE_INTESTINE                      0.043010  0.114406  0.003146
# 253J_URINARY_TRACT                          0.190601  0.212744  0.004571
#
#                                                ULBP2     ULBP3      ULK1  \
# line
# HEL_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE      0.251080  0.012645  0.125621
# HEL9217_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE  0.002710  0.030146  0.030472
# LS513_LARGE_INTESTINE                       0.053709  0.064741  0.005785
# C2BBE1_LARGE_INTESTINE                      0.085866  0.065066  0.040335
# 253J_URINARY_TRACT                          0.027059  0.261925  0.305681
#
#                                                 ULK2      ULK3      ULK4
# line
# HEL_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE      0.001633  0.026469  0.000128
# HEL9217_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE  0.000230  0.022362  0.000945
# LS513_LARGE_INTESTINE                       0.053324  0.015700  0.000100
# C2BBE1_LARGE_INTESTINE                      0.101210  0.014466  0.000668
# 253J_URINARY_TRACT                          0.104093  0.022448  0.001405
#
# [5 rows x 16383 columns]

# %%
df_rppa=df_rppa.rename(columns={'Unnamed: 0':'line'})
df_rppa.set_index("line", inplace=True)
df_rppa.head()
# Out:
#                                              YWHAB     YWHAE     YWHAZ  \
# line
# DMS53_LUNG                               -0.104888  0.060414  0.309068
# SW1116_LARGE_INTESTINE                    0.358504 -0.180291 -0.041237
# NCIH1694_LUNG                             0.028738  0.071902 -0.094847
# P3HR1_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE  0.120039 -0.066802 -0.128007
# HUT78_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE -0.268997 -0.060281 -0.137881
#
#                                           EIF4EBP1  EIF4EBP1.1  EIF4EBP1.2  \
# line
# DMS53_LUNG                               -0.075506    0.230359    0.198304
# SW1116_LARGE_INTESTINE                   -0.286629   -0.877406   -1.026948
# NCIH1694_LUNG                             0.285069    1.321551    0.620703
# P3HR1_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE -0.552081   -0.292428   -1.415935
# HUT78_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE -0.398729   -0.095622   -0.533905
#
#                                           EIF4EBP1.3   TP53BP1      ARAF  \
# line
# DMS53_LUNG                                 -0.030541  0.455889  0.090484
# SW1116_LARGE_INTESTINE                     -0.462761 -0.011197  0.605330
# NCIH1694_LUNG                              -0.439484  0.195007  0.036221
# P3HR1_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE   -0.138858 -0.066122 -0.346564
# HUT78_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE    0.054245 -0.573022 -0.162968
#
#                                           ACACA ACACB  ...    TSC2.1  \
# line                                                   ...
# DMS53_LUNG                                   0.268448  ... -0.099433
# SW1116_LARGE_INTESTINE                      -0.614974  ... -0.109777
# NCIH1694_LUNG                                0.767920  ...  0.154344
# P3HR1_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE     0.586421  ...  0.040106
# HUT78_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE    -0.691478  ... -0.466919
#
#                                               VAV1       KDR       VHL  \
# line
# DMS53_LUNG                               -0.486715 -1.147858  0.133876
# SW1116_LARGE_INTESTINE                    0.349330  0.770148  0.984297
# NCIH1694_LUNG                            -0.478189 -1.185530  1.273013
# P3HR1_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE  5.923830 -3.893832 -2.499188
# HUT78_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE  5.475880 -0.561973 -0.500953
#
#                                               XBP1     XRCC1      YAP1  \
# line
# DMS53_LUNG                               -0.075812 -0.144388 -1.090303
# SW1116_LARGE_INTESTINE                   -0.168138 -0.004905  0.189294
# NCIH1694_LUNG                            -0.240413  0.476633 -1.367465
# P3HR1_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE  0.632758  0.025639 -1.189180
# HUT78_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE -0.261494  0.358679 -0.951686
#
#                                             YAP1.1      YBX1    YBX1.1
# line
# DMS53_LUNG                               -2.109324  0.178104  0.246541
# SW1116_LARGE_INTESTINE                   -0.283593  0.255972 -0.121134
# NCIH1694_LUNG                            -2.525695 -0.137880 -0.451282
# P3HR1_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE -3.056863  0.025997 -0.465205
# HUT78_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE -3.247388 -0.151424 -0.145426
#
# [5 rows x 214 columns]

# %% [markdown]
# ## Finding the common Cell lines between CRISPR data and RPPA data

# %%
#crispr_genes=df_crispr.columns
rppa_cell_lines=df_rppa.index.tolist()
crispr_cell_lines=df_crispr.index.tolist()

# %%
crispr_cell_lines[:10]
# Out:
# ['HEL_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE',
#  'HEL9217_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE',
#  'LS513_LARGE_INTESTINE',
#  'C2BBE1_LARGE_INTESTINE',
#  '253J_URINARY_TRACT',
#  'HCC827_LUNG',
#  'ONCODG1_OVARY',
#  'HS294T_SKIN',
#  'NCIH1581_LUNG',
#  'SKBR3_BREAST']

# %%
rppa_cell_lines[:10]
# Out:
# ['DMS53_LUNG',
#  'SW1116_LARGE_INTESTINE',
#  'NCIH1694_LUNG',
#  'P3HR1_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE',
#  'HUT78_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE',
#  'UMUC3_URINARY_TRACT',
#  'HOS_BONE',
#  'HUNS1_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE',
#  'AML193_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE',
#  'RVH421_SKIN']

# %% [markdown]
# ### Similar Cell lines

# %%
similar_cell_lines=[]
for i in crispr_cell_lines:
    for j in rppa_cell_lines:
        if i==j:
            similar_cell_lines.append(i)

# %%
similar_cell_lines[:10]
# Out:
# ['HEL_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE',
#  'HEL9217_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE',
#  'LS513_LARGE_INTESTINE',
#  'C2BBE1_LARGE_INTESTINE',
#  '253J_URINARY_TRACT',
#  'HCC827_LUNG',
#  'ONCODG1_OVARY',
#  'HS294T_SKIN',
#  'NCIH1581_LUNG',
#  'SKBR3_BREAST']

# %%
len(similar_cell_lines)
# Out:
# 444

# %%
print("There are total:{} similar cell lines between the two dataset".format(len(similar_cell_lines)))
# Out:
# There are total:444 similar cell lines between the two dataset

# %% [markdown]
# ## Selecting All RPPA data as the features and stored in the X data frame

# %%
X=df_rppa.loc[similar_cell_lines]

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 444 entries, HEL_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE to PLCPRF5_LIVER
# Columns: 214 entries, YWHAB to YBX1.1
# dtypes: float64(214)
# memory usage: 745.8+ KB

# %% [markdown]
# ## Selecting All CRISPR gene data as Predicted values stored in the Y data frame

# %%
Y=df_crispr.loc[similar_cell_lines]

# %%
Y.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 444 entries, HEL_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE to PLCPRF5_LIVER
# Columns: 16383 entries, A1BG to ULK4
# dtypes: float64(16382), int64(1)
# memory usage: 55.5+ MB

# %% [markdown]
# ### Normalizing RPPA data

# %%
def normalize(df):
    result = df.copy()
    for feature_name in df.columns:
        max_value = df[feature_name].max()
        min_value = df[feature_name].min()
        result[feature_name] = (df[feature_name] - min_value) / (max_value - min_value)
    return result

# %%
X=normalize(X)

# %%
X.head()
# Out:
#                                                YWHAB     YWHAE     YWHAZ  \
# line
# HEL_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE      0.410411  0.171464  0.519696
# HEL9217_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE  0.582449  0.082607  0.566652
# LS513_LARGE_INTESTINE                       0.493872  0.131103  0.603693
# C2BBE1_LARGE_INTESTINE                      0.513429  0.156913  0.387971
# 253J_URINARY_TRACT                          0.335676  0.110797  0.368828
#
#                                             EIF4EBP1  EIF4EBP1.1  EIF4EBP1.2  \
# line
# HEL_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE      0.597963    0.485744    0.737962
# HEL9217_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE  0.703941    0.487497    0.678673
# LS513_LARGE_INTESTINE                       0.345025    0.240713    0.102336
# C2BBE1_LARGE_INTESTINE                      0.539100    0.430711    0.597427
# 253J_URINARY_TRACT                          0.555116    0.463385    0.439026
#
#                                             EIF4EBP1.3   TP53BP1      ARAF  \
# line
# HEL_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE        0.352113  0.545474  0.284560
# HEL9217_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE    0.535182  0.635575  0.167683
# LS513_LARGE_INTESTINE                         0.205138  0.570898  0.260385
# C2BBE1_LARGE_INTESTINE                        0.277486  0.689896  0.173746
# 253J_URINARY_TRACT                            0.502746  0.814759  0.416977
#
#                                             ACACA ACACB  ...    TSC2.1  \
# line                                                     ...
# HEL_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE         0.609300  ...  0.387633
# HEL9217_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE     0.605910  ...  0.081860
# LS513_LARGE_INTESTINE                          0.487377  ...  0.162369
# C2BBE1_LARGE_INTESTINE                         0.688491  ...  0.151452
# 253J_URINARY_TRACT                             0.438136  ...  0.380809
#
#                                                 VAV1       KDR       VHL  \
# line
# HEL_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE      0.930686  0.410810  0.174698
# HEL9217_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE  0.864116  0.285005  0.070033
# LS513_LARGE_INTESTINE                       0.177023  0.594484  0.462292
# C2BBE1_LARGE_INTESTINE                      0.196299  0.807169  0.368955
# 253J_URINARY_TRACT                          0.148625  0.636228  0.315998
#
#                                                 XBP1     XRCC1      YAP1  \
# line
# HEL_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE      0.427952  0.667905  0.079482
# HEL9217_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE  0.529039  0.647043  0.014608
# LS513_LARGE_INTESTINE                       0.554430  0.668121  0.327760
# C2BBE1_LARGE_INTESTINE                      0.278468  0.663494  0.508307
# 253J_URINARY_TRACT                          0.650870  0.678761  0.317560
#
#                                               YAP1.1      YBX1    YBX1.1
# line
# HEL_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE      0.144868  0.196799  0.738371
# HEL9217_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE  0.079377  0.300193  0.443751
# LS513_LARGE_INTESTINE                       0.509503  0.314158  0.421664
# C2BBE1_LARGE_INTESTINE                      0.613539  0.227166  0.509321
# 253J_URINARY_TRACT                          0.502301  0.516555  0.414583
#
# [5 rows x 214 columns]

# %%
Y.head()
# Out:
#                                                 A1BG      A1CF       A2M  \
# line
# HEL_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE      0.002472  0.006113  0.080820
# HEL9217_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE  0.106867  0.002193  0.013620
# LS513_LARGE_INTESTINE                       0.008004  0.005757  0.022515
# C2BBE1_LARGE_INTESTINE                      0.005477  0.013870  0.010608
# 253J_URINARY_TRACT                          0.001426  0.006870  0.020701
#
#                                                A2ML1   A3GALT2    A4GALT  \
# line
# HEL_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE      0.014331  0.011727  0.086325
# HEL9217_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE  0.003971  0.057068  0.181176
# LS513_LARGE_INTESTINE                       0.002067  0.004548  0.002647
# C2BBE1_LARGE_INTESTINE                      0.006887  0.007972  0.012466
# 253J_URINARY_TRACT                          0.000096  0.031714  0.157628
#
#                                                A4GNT      AAAS      AACS  \
# line
# HEL_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE      0.000195  0.385731  0.000323
# HEL9217_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE  0.006674  0.226020  0.022460
# LS513_LARGE_INTESTINE                       0.006611  0.350966  0.015407
# C2BBE1_LARGE_INTESTINE                      0.007143  0.654158  0.002847
# 253J_URINARY_TRACT                          0.008184  0.325639  0.005510
#
#                                                AADAC  ...  UHRF1BP1L  \
# line                                                  ...
# HEL_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE      0.002680  ...   0.000226
# HEL9217_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE  0.017682  ...   0.129011
# LS513_LARGE_INTESTINE                       0.000335  ...   0.007540
# C2BBE1_LARGE_INTESTINE                      0.005807  ...   0.011120
# 253J_URINARY_TRACT                          0.005072  ...   0.002486
#
#                                                UHRF2     UIMC1     ULBP1  \
# line
# HEL_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE      0.482277  0.088692  0.105547
# HEL9217_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE  0.173723  0.111182  0.248581
# LS513_LARGE_INTESTINE                       0.009939  0.298588  0.004260
# C2BBE1_LARGE_INTESTINE                      0.043010  0.114406  0.003146
# 253J_URINARY_TRACT                          0.190601  0.212744  0.004571
#
#                                                ULBP2     ULBP3      ULK1  \
# line
# HEL_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE      0.251080  0.012645  0.125621
# HEL9217_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE  0.002710  0.030146  0.030472
# LS513_LARGE_INTESTINE                       0.053709  0.064741  0.005785
# C2BBE1_LARGE_INTESTINE                      0.085866  0.065066  0.040335
# 253J_URINARY_TRACT                          0.027059  0.261925  0.305681
#
#                                                 ULK2      ULK3      ULK4
# line
# HEL_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE      0.001633  0.026469  0.000128
# HEL9217_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE  0.000230  0.022362  0.000945
# LS513_LARGE_INTESTINE                       0.053324  0.015700  0.000100
# C2BBE1_LARGE_INTESTINE                      0.101210  0.014466  0.000668
# 253J_URINARY_TRACT                          0.104093  0.022448  0.001405
#
# [5 rows x 16383 columns]

# %% [markdown]
# # Linear Regression

# %%
import numpy as np
# Linear Regression for Training data 
def linear_regression_train(X_train, y_train):
    from sklearn.linear_model import LinearRegression
    model = LinearRegression()
    model = model.fit(X_train, y_train)
    ## R-squared value
    r_sq = model.score(X_train, y_train)

    ## Training RMSE for 10-fold-cross validation
    from sklearn.model_selection import cross_val_score
    mse_training=-cross_val_score(model, X_train, y_train, cv=10, scoring='neg_mean_squared_error').mean()
    rmse_training= np.sqrt(mse_training)
    
    return r_sq, rmse_training, model

# Linear Regression for Testing data 
def linear_regression_test(X_test, y_test, model):
    y_pred = model.predict(X_test)
    
    ## RMSE for testing
    from sklearn.metrics import mean_squared_error
    mse_linear_regression=mean_squared_error(y_test, y_pred)
    rmse_lr_testing = np.sqrt(mse_linear_regression)

    return rmse_lr_testing

# %% [markdown]
# # Random Forest

# %%
# Random Forest Regression for Training data 
def randomforest_regression_train(X_train, y_train):
    from sklearn.ensemble import RandomForestRegressor
    Model = RandomForestRegressor(n_estimators = 200, 
                                  random_state = 0,
                                  oob_score = True)
    rf_model=Model.fit(X_train, y_train)
    ## R-squared value
    r_sq_rf = rf_model.score(X_train, y_train)
    
    ## Training RMSE for 10-fold-cross validation
    from sklearn.model_selection import cross_val_score
    mse_training=-cross_val_score(rf_model, X_train, y_train, cv=10, scoring='neg_mean_squared_error').mean()
    rmse_training= np.sqrt(mse_training)
    
    return r_sq_rf, rmse_training, rf_model

# Random Forest Regression for Testing data 
def randomforest_regression_test(X_test, y_test, rf_model):
    y_pred = rf_model.predict(X_test)
    from sklearn.metrics import mean_squared_error
    mse_rf=mean_squared_error(y_test, y_pred)
    rmse_rf_testing= np.sqrt(mse_rf)

    return rmse_rf_testing

# %% [markdown]
# # Baseline Model

# %% [markdown]
# In the paper, I have seen this line "The baseline model used to exclude failed predictions by using the averaged dependency score as the predicted values". So, to calculate the RMSE of Base model, I took an average of the selected predictive column. And then put the average value as the prediction values like in the Table below. Then I calculated the RMSE of the Base model. Here, 0.014147 is the average value of the predicted gene cell line values.
#
# | y_train | y_pred
# | :- :| :-:
# | 0.006783 | 0.014147
# | 0.002031 | 0.014147
# | 0.002172 | 0.014147
# | 0.021932 | 0.014147
# | 0.002132 | 0.014147
# | 0.001103 | 0.014147
# | 0.012150 | 0.014147
# | 0.020812 |0.014147
# | 0.007271 |0.014147
# | 0.008655 | 0.014147
# | 0.000969 | 0.014147
# | 0.019559 | 0.014147
# | 0.010369 | 0.014147
# | 0.005347 | 0.014147
# | 0.033292 | 0.014147
# | 0.013280 | 0.014147
# | 0.102510 | 0.014147
# | 0.004294 | 0.014147
# | 0.002820 | 0.014147
# | 0.005472 | 0.014147

# %%
def baseline_training(y_train,y):
    base_train_pred=[]
    for x in y_train:
        if x is not y.mean(axis = 0):
            base_train_pred.append(y.mean(axis = 0))
        else:
            base_train_pred.append(x)
    base_train_pred=np.array(base_train_pred)
    
    from sklearn.metrics import mean_squared_error
    mse_base_train_pred=mean_squared_error(y_train, base_train_pred)
    rmse_base_train_pred= np.sqrt(mse_base_train_pred)

    return rmse_base_train_pred

def baseline_testing(y_test,y):
    base_test_pred=[]
    for x in y_test:
        if x is not y.mean(axis = 0):
            base_test_pred.append(y.mean(axis = 0))
        else:
            base_test_pred.append(x)
    base_test_pred=np.array(base_test_pred)
    
    from sklearn.metrics import mean_squared_error
    mse_baseline=mean_squared_error(y_test, base_test_pred)
    rmse_baseline_test_pred= np.sqrt(mse_baseline)

    return rmse_baseline_test_pred

# %% [markdown]
# # Testing the first 100 genes

# %%
flagged=[]
best={}
exclusion=[]
for i in range(100):
    y=Y.iloc[:,i]
    name=df_crispr.iloc[:,i].name
    from sklearn.model_selection import train_test_split
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.7, random_state = 0)

    ##Linear Regression
    r_sq_lr, rmse_training_lr, model = linear_regression_train(X_train, y_train)
    rmse_lr_testing = linear_regression_test(X_test, y_test, model)

    ##Baseline model
    rmse_base_train_pred = baseline_training(y_train,y)
    rmse_baseline_test_pred = baseline_testing(y_test,y)

    ##Random Forrest
    r_sq_rf, rmse_training_rf, rf_model = randomforest_regression_train(X_train, y_train)
    rmse_rf_testing = randomforest_regression_test(X_test, y_test, rf_model)

    ## Finding if the gene has cancer dependency
    if ((rmse_base_train_pred>rmse_training_lr) and (rmse_baseline_test_pred>rmse_lr_testing)) or ((rmse_base_train_pred>rmse_training_rf) and (rmse_baseline_test_pred>rmse_rf_testing)):
        flagged.append(name)
        print("Dependency Found in:",name)
        ## Finfing the best classifier model from Linear and Random Forrest Regression
        if r_sq_lr<r_sq_rf:
            best[name]='Random Forrest Regression'
        else:
            best[name]='Linear Regression'
    else:
        exclusion.append(name)
# Out:
# Dependency Found in: AASDHPPT

# %%
print("Cancer Dependency Genes:{},{}".format(len(flagged),flagged))
# print("Cancer Exclusion Genes:",len(exclusion))
print("Cancer Exclusion Genes:{}".format(len(exclusion)))
# Out:
# Cancer Dependency Genes:1,['AASDHPPT']
# Cancer Exclusion Genes:99

# %%
best
# Out:
# {'AASDHPPT': 'Linear Regression'}
